# %% [markdown]
# Update descriptions with already saved ones in description file.

# %% [markdown]
# Before using this notebook, make sure you have follow these steps:
# 1) make sure the `parameters.yml` file in the same directory.
# 2) Then run the code for zero timesteps with `../../run_fargo start -N 0 config.yml` inside this directory. `WriteDefaultValues: Yes` needs to be in the configfile.

# %%
import yaml
try:
    with open("parameters.yml", "r") as infile:
        parameters = yaml.safe_load(infile)
except FileNotFoundError:
    paramters = {}

# %%
parameters
# Out:
# {'ALPHAVISCOSITY': {'choices': '',
#   'default': 0,
#   'deprecated': True,
#   'description': 'Specify the value of alpha for the alpha viscosity model.',
#   'newname': 'ViscousAlpha'},
#  'AccreteWithoutDiskFeedback': {'choices': '',
#   'default': False,
#   'description': 'Let planets accrete without disk feedback being enabled.',
#   'type': 'bool',
#   'unitsupport': False},
#  'Adiabatic': {'choices': '',
#   'default': False,
#   'deprecated': True,
#   'description': 'Deprecated. Dont use this anymore.',
#   'hint': 'EquationOfState: Ideal',
#   'newname': 'none',
#   'type': 'string',
#   'unitsupport': False},
#  'AdiabaticIndex': {'choices': '',
#   'default': 'none',
#   'description': 'Numerical value or FIT_ISOTHERMAL (only for polytropic equation of state)',
#   'type': 'double',
#   'unitsupport': False},
#  'AlphaCold': {'choices': '',
#   'default': 0.01,
#   'description': 'Alpha value for the cold state in scurve alpha.',
#   'type': 'double',
#   'unitsupport': False},
#  'AlphaHot': {'choices': '',
#   'default': 0.1,
#   'description': 'Alpha value for the hot state in scurve alpha.',
#   'type': 'double',
#   'unitsupport': False},
#  'AlphaMode': {'choices': '0, 1, 2',
#   'default': 0,
#   'description': 'Select how the viscosity is calculated. 0: Const alpha  1: Scurve Alpha  2: Nbody distance dependend',
#   'type': 'int',
#   'unitsupport': False},
#  'AlphaThreshold': {'choices': 'positive values',
#   'default': 5000,
#   'deprecated': True,
#   'description': '?Threshold value for viscosity stabalized?',
#   'newname': 'none',
#   'type': 'double',
#   'unitsupport': False},
#  'ArtificialViscosity': {'choices': 'none, TW, SN',
#   'default': 'none',
#   'description': 'Type of artificial viscosity [default = SN] TODO: change default to TW',
#   'type': 'string',
#   'unitsupport': False},
#  'ArtificialViscosityDissipation': {'choices': 'yes, no',
#   'default': True,
#   'description': 'Use artificial viscosity in dissipation function.',
#   'type': 'bool',
#   'unitsupport': False},
#  'ArtificialViscosityFactor': {'choices': '',
#   'default': 'none',
#   'description': 'Artificial viscosity factor/constant (von Neumann-Richtmyer constant).',
#   'type': 'double',
#   'unitsupport': False},
#  'AspectRatio': {'choices': '',
#   'default': 'none',
#   'description': 'Set the reference value for the aspect ratio: h = ASPECTRATIO * r^{1+flaringindex}',
#   'type': 'double',
#   'unitsupport': False},
#  'AspectRatioMode': {'choices': '0, 1, 2',
#   'default': 'none',
#   'description': 'Compute aspectratio with respect to: 0: Primary object, 1: Nbody system, 2: Nbody center of mass',
#   'type': 'int',
#   'unitsupport': False},
#  'BitwiseExactRestarting': {'choices': 'yes, no',
#   'default': False,
#   'description': 'Write out Qplus and Qminus 2D arrays to snapshot for bitwise exact restarting. This is really usefull to test development changes in the code.',
#   'type': 'bool',
#   'unitsupport': False},
#  'BodyForceFromPotential': {'choices': '',
#   'default': True,
#   'description': 'Consider the gravitational force from the Nbody onto the disk via the potential.',
#   'type': 'bool',
#   'unitsupport': False},
#  'CFL': {'choices': '',
#   'default': 'none',
#   'description': 'CFL factor.',
#   'type': 'double',
#   'unitsupport': False},
#  'CFLmaxVar': {'choices': '',
#   'default': 'none',
#   'description': 'Maximum variation of the CFL timestep over one iteration.',
#   'type': 'double',
#   'unitsupport': False},
#  'CICPLANET': {'choices': '',
#   'default': False,
#   'description': '?',
#   'type': 'bool',
#   'unitsupport': False},
#  'CartesianParticles': {'choices': 'yes, no',
#   'default': False,
#   'description': 'Particle coordinates in cartesian coordinates.',
#   'type': 'bool',
#   'unitsupport': False},
#  'CenterProfileDensityCorrectionFactor': {'choices': '',
#   'default': 1,
#   'description': '?',
#   'type': 'double',
#   'unitsupport': False},
#  'CircumBinaryDecayExponent': {'choices': '',
#   'default': 0.75,
#   'description': '?',
#   'type': 'double',
#   'unitsupport': False},
#  'CircumBinaryDecayWidth': {'choices': '',
#   'default': 0.84,
#   'description': '?',
#   'type': 'double',
#   'unitsupport': False},
#  'CircumBinaryRing': {'choices': 'yes, no',
#   'default': False,
#   'description': 'Initialize a circumbinary ring.',
#   'type': 'bool',
#   'unitsupport': False},
#  'CircumBinaryRingEnhancementFactor': {'choices': '',
#   'default': 2.5,
#   'description': '?',
#   'type': 'double',
#   'unitsupport': False},
#  'CircumBinaryRingPosition': {'choices': '',
#   'default': 4.5,
#   'description': 'Position of the circumbinary ring.',
#   'type': 'double',
#   'unitsupport': False},
#  'CircumBinaryRingWidth': {'choices': '',
#   'default': 0.6,
#   'description': 'Width of the circumbinary ring.',
#   'type': 'double',
#   'unitsupport': False},
#  'CompatibilityNoStarSmoothing': {'choices': '',
#   'default': False,
#   'description': '',
#   'type': 'bool',
#   'unitsupport': False},
#  'CompatibilitySmoothingPlanetLoc': {'choices': 'yes, no',
#   'default': False,
#   'description': 'Use the scale height at the planet position for the smoothing length calculation instead of the scaleheight at the cell.',
#   'type': 'bool',
#   'unitsupport': False},
#  'ConstantViscosity': {'choices': '',
#   'default': 0,
#   'description': 'Set a constant kinetic viscosity.',
#   'oldname': 'Viscosity',
#   'type': 'double',
#   'unitsupport': False},
#  'CoolingBeta': {'choices': '',
#   'default': 'none',
#   'description': 'Paramter value of beta for the beta cooling.',
#   'type': 'double',
#   'unitsupport': False},
#  'CoolingBetaLocal': {'choices': 'yes, no',
#   'default': False,
#   'description': 'Enable beta cooling Q- = T * Omega/beta',
#   'type': 'bool',
#   'unitsupport': False},
#  'CoolingBetaRampUp': {'choices': '',
#   'default': 0,
#   'description': 'Increase beta cooling on this timescale.',
#   'type': 'double',
#   'unitsupport': False},
#  'CoolingBetaReference': {'choices': 'zero, initial, aspectratio',
#   'default': 'none',
#   'description': 'Reference temperature/energy profile for beta cooling.',
#   'type': 'string',
#   'unitsupport': False},
#  'CoolingRadiativeFactor': {'choices': '',
#   'default': 'none',
#   'description': 'Fudge factor for radiative cooling. Leave this at 1.',
#   'type': 'double',
#   'unitsupport': False},
#  'CoolingRadiativeLocal': {'choices': 'yes, no',
#   'default': False,
#   'deprecated': True,
#   'description': 'Enable local radiative cooling Q- = 2 * sigma_R * T_eff^4.',
#   'hint': 'SurfaceCooling: thermal',
#   'newname': 'none'},
#  'CoolingScurve': {'choices': 'yes, no',
#   'default': False,
#   'deprecated': True,
#   'description': 'Enable Scurve Cooling',
#   'hint': 'SurfaceCooling: scurve',
#   'newname': 'none'},
#  'CorotationReferenceBody': {'choices': 'positive integers',
#   'default': 1,
#   'description': 'Select the Nbody object which is the reference object for the automatic calculation of the corotation angular velocity for a rotating frame.',
#   'type': 'unsigned int',
#   'unitsupport': False},
#  'CorrectDiskSelfgravity': {'choices': 'yes, no',
#   'default': True,
#   'description': 'Substract the azimuthal average of the surface density in the calculation of torques on Nbody object to make the disk and Nbody have the same central mass around which they orbit. See Baruteau & Masset (2008). [default=not selfgravity turned on]',
#   'type': 'bool',
#   'unitsupport': False},
#  'DT': {'choices': '',
#   'default': 1,
#   'deprecated': True,
#   'description': 'Time between two analysis outputs. For default units, 2PI = 1 orbit at r=1.',
#   'newname': 'MonitorTimestep'},
#  'Damping': {'choices': 'yes, no',
#   'default': False,
#   'description': 'Use a wave-damping zone. Exponentially damp to a profile.',
#   'type': 'bool',
#   'unitsupport': False},
#  'DampingEnergyInner': {'choices': 'initial, mean, zero, none',
#   'default': 'none',
#   'description': 'Target quantity of energy at inner boundary',
#   'type': 'string',
#   'unitsupport': False},
#  'DampingEnergyOuter': {'choices': 'initial, mean, zero, none',
#   'default': 'none',
#   'description': 'Target quantity of energy at outer boundary',
#   'type': 'string',
#   'unitsupport': False},
#  'DampingInnerLimit': {'choices': 'positive floats',
#   'default': 'none',
#   'description': 'Set the outer limit of the inner wave damping zone: Rmin*Limit. Zone is diabled for limit < 1. Rmin is the radius of the inner boundary.',
#   'type': 'double',
#   'unitsupport': False},
#  'DampingOuterLimit': {'choices': 'positive floats',
#   'default': 'none',
#   'description': 'Set the inner limit of the outer wave damping zone: Rmax*Limit. Zone is diabled for limit > 1. Rmax is the radius of the outer boundary.',
#   'type': 'double',
#   'unitsupport': False},
#  'DampingSurfaceDensityInner': {'choices': 'initial, mean, zero, none',
#   'default': 'none',
#   'description': 'Target quantity of surface density at inner boundary',
#   'type': 'string',
#   'unitsupport': False},
#  'DampingSurfaceDensityOuter': {'choices': 'initial, mean, zero, none',
#   'default': 'none',
#   'description': 'Target quantity of surface density at outer boundary',
#   'type': 'string',
#   'unitsupport': False},
#  'DampingTimeFactor': {'choices': '',
#   'default': 'none',
#   'description': 'Damping time factor. Values will be exponentially damped on a timescale of factor*Keplerian Period at boundary radius.',
#   'type': 'double',
#   'unitsupport': False},
#  'DampingTimeRadiusOuter': {'choices': 'positive floats',
#   'default': 'none',
#   'description': 'Reference radius for the outer damping time. default: Outer domain radius RMAX',
#   'type': 'double',
#   'unitsupport': False},
#  'DampingVAzimuthalInner': {'choices': 'initial, mean, zero, none',
#   'default': 'none',
#   'description': 'Target quantity of azimuthal velocity at inner boundary',
#   'type': 'string',
#   'unitsupport': False},
#  'DampingVAzimuthalOuter': {'choices': 'initial, mean, zero, none',
#   'default': 'none',
#   'description': 'Target quantity of azimuthal velocity at outer boundary',
#   'type': 'string',
#   'unitsupport': False},
#  'DampingVRadialInner': {'choices': 'initial, mean, zero, none',
#   'default': 'none',
#   'description': 'Target quantity of radial velocity at inner boundary.',
#   'type': 'string',
#   'unitsupport': False},
#  'DampingVRadialOuter': {'choices': 'initial, mean, zero, none',
#   'default': 'none',
#   'description': 'Target quantity of radial velocity at outer boundary',
#   'type': 'string',
#   'unitsupport': False},
#  'DebugOutputs': {'choices': 'yes, no',
#   'default': False,
#   'deprecated': True,
#   'description': 'Write out additional debug files.',
#   'newname': 'none',
#   'type': 'bool',
#   'unitsupport': False},
#  'DensityFactor': {'choices': '',
#   'default': 2.5066282746310002,
#   'description': 'Factor for convertion from surface density to density. Leave this as it is! [default = sqrt(2.0*pi)]',
#   'type': 'double',
#   'unitsupport': False},
#  'Disk': {'choices': 'yes, no',
#   'default': True,
#   'description': 'Turn on hydro part of the simulation. Set this to no to, e.g., test the dust module.',
#   'type': 'bool',
#   'unitsupport': False},
#  'DiskFeedback': {'choices': 'yes, no',
#   'default': True,
#   'description': 'Enable gravitational forces from the disk onto the planets. Enable migration.',
#   'type': 'bool',
#   'unitsupport': False},
#  'DiskMass': {'choices': '',
#   'default': 0.01,
#   'description': 'In case of SetSigma0=yes, use this mass as diskmass.',
#   'type': 'double',
#   'unitsupport': False},
#  'DiskRadiusMassFraction': {'choices': '',
#   'default': 0.99,
#   'description': 'Calculation of the disk radius: this fraction of the total mass is contained within the disk radius.',
#   'type': 'double',
#   'unitsupport': False},
#  'DoWrite1DFiles': {'choices': 'yes, no',
#   'default': True,
#   'description': 'Write out 1D files additional to the 2D output.',
#   'type': 'bool',
#   'unitsupport': False},
#  'DomegaDrZero': {'choices': 'yes, no',
#   'default': False,
#   'deprecated': True,
#   'description': 'Set dOmega/dr = 0 at outer boundary',
#   'hint': 'OuterBoundaryAzi = zeroshear',
#   'newname': 'none'},
#  'EnergyCondition': {'choices': 'Profile, 1D, 2D',
#   'default': 'Profile',
#   'description': 'Initialize energy by Profile, 1D data file or 2D data file.',
#   'type': 'string',
#   'unitsupport': False},
#  'EnergyFilename': {'choices': '',
#   'default': '',
#   'description': 'File to read energy from (when Condition = 1D or 2D)',
#   'type': 'string',
#   'unitsupport': False},
#  'EquationOfState': {'choices': 'Isothermal, Ideal, PVTE, Polytropic ',
#   'default': 'none',
#   'description': 'Select the equation of state.',
#   'type': 'string',
#   'unitsupport': False},
#  'ExplicitViscosity': {'choices': 'yes, no',
#   'default': False,
#   'deprecated': True,
#   'description': 'Consider explicit viscocsity.',
#   'hint': 'Set ViscousAlpha > 0 or ConstantViscosity > 0',
#   'newname': 'none',
#   'type': 'bool',
#   'unitsupport': False},
#  'ExponentialCellSizeFactor': {'choices': '',
#   'default': 1.41,
#   'description': 'Cell size increase factor to build an exponential grid. Only relevant for exponential grid type.',
#   'type': 'double',
#   'unitsupport': False},
#  'FeatureSize': {'choices': '',
#   'default': 0.014000000000000002,
#   'description': 'Feature size of the open somplex algorithm.',
#   'type': 'double',
#   'unitsupport': False},
#  'FirstDT': {'choices': '',
#   'default': 1e-09,
#   'description': 'Initialization value for the hydro dt in case of hydro simulations turned off. Otherwise CFL dt is used.',
#   'type': 'double',
#   'unitsupport': False},
#  'FlaringIndex': {'choices': '',
#   'default': 'none',
#   'description': 'Specify the flaring index. H = H0 * r^{1+flaringindex}.',
#   'type': 'double',
#   'unitsupport': False},
#  'FluxLimiter': {'choices': 'VanLeer, MC',
#   'default': 'VanLeer',
#   'description': 'Selec the flux limiter for the upwind scheme.',
#   'type': 'string',
#   'unitsupport': False},
#  'ForcedCircular': {'choices': 'yes, no',
#   'default': False,
#   'deprecated': True,
#   'description': 'Keep the eccentricity of the planet to zero. [default = no]',
#   'newname': 'none',
#   'type': 'bool',
#   'unitsupport': False},
#  'Frame': {'choices': 'F, C',
#   'default': 'none',
#   'description': 'Select whether the rotating frame has a fixed angular velocity (F) or if it is updated (C).  F: Fixed, C: Corotating',
#   'type': 'string',
#   'unitsupport': False},
#  'HeatingCoolingCFLlimit': {'choices': '',
#   'default': 'none',
#   'description': 'Energy change dT/T in substep3 only allowed to change by this fraction times CFL.',
#   'type': 'double',
#   'unitsupport': False},
#  'HeatingStar': {'choices': 'yes, no',
#   'default': False,
#   'deprecated': True,
#   'description': 'Enable irradiation heating by the star.',
#   'hint': 'Set temperature of any Nbody object > 0 to enable irradiation from this object.',
#   'newname': 'none',
#   'type': 'bool',
#   'unitsupport': False},
#  'HeatingStarFactor': {'choices': 'positive value',
#   'deprecated': True,
#   'description': 'Modulate the heating by this factor.',
#   'hint': 'Change the temperature of the Nbody object to modulate the heating.',
#   'newname': 'none',
#   'type': 'double',
#   'unitsupport': False},
#  'HeatingStarRampingTime': {'choices': 'positive value',
#   'deprecated': True,
#   'description': 'Ramp up the heating over this time.',
#   'hint': "Use key 'irradiation ramp-up time' for Nbody objects.",
#   'newname': 'none',
#   'type': 'double',
#   'unitsupport': False},
#  'HeatingStarSimple': {'choices': 'yes, no',
#   'default': False,
#   'deprecated': True,
#   'description': 'Enable simple irradiation heating by the star solely based on distance.',
#   'hint': 'This is now the only option.',
#   'newname': 'none',
#   'type': 'bool',
#   'unitsupport': False},
#  'HeatingViscous': {'choices': 'yes, no',
#   'default': True,
#   'description': 'Enable viscous heating. TODO: change default to yes',
#   'type': 'bool',
#   'unitsupport': False},
#  'HeatingViscousFactor': {'choices': 'positive float.',
#   'default': 1,
#   'description': 'Fudge factor for viscous heating. Leave this at 1.',
#   'type': 'double',
#   'unitsupport': False},
#  'HydroFrameCenter': {'choices': 'primary, binary, tertiary, quatirary, all',
#   'default': 'none',
#   'description': 'Specify the origin of the simulation grid. Primary uses the central object, binary/tertiary/quatirary/all uses the center of mass of the first 2/3/4/all nbody objects',
#   'type': 'string',
#   'unitsupport': False},
#  'HydrogenMassFraction': {'choices': '',
#   'default': 'none',
#   'description': '',
#   'type': 'double',
#   'unitsupport': False},
#  'ImposedDiskDrift': {'choices': '',
#   'default': 0,
#   'description': 'Initialize with an imposed accretion through the disk. ?',
#   'type': 'double',
#   'unitsupport': False},
#  'IndirectTermMode': {'choices': '0, 1',
#   'default': 'none',
#   'description': 'Select the way the indirect term is calculated. You likely want 0. 0: indirect term from rebound with shift; 1: euler with shift (original)',
#   'type': 'int',
#   'unitsupport': False},
#  'InitializePureKeplerian': {'choices': 'yes, no',
#   'default': False,
#   'description': 'Initialize VRadial=0 and VAzimuthal=(GM/r)^(1/2)',
#   'type': 'bool',
#   'unitsupport': False},
#  'InitializeVradialZero': {'choices': 'yes, no',
#   'default': False,
#   'description': 'Initialize VRadial=0  [default = no]',
#   'type': 'bool',
#   'unitsupport': False},
#  'InnerBoundary': {'choices': 'Open, Reflective/Rigid, Viscous, ZeroGradient, PrescribedTimeVariable, BoundaryLayer',
#   'default': 'none',
#   'description': 'Boundary condition at the inner boundary.',
#   'type': 'string',
#   'unitsupport': False},
#  'InnerBoundaryEnergy': {'choices': '',
#   'default': 'infer',
#   'description': '',
#   'type': 'string',
#   'unitsupport': False},
#  'InnerBoundarySigma': {'choices': '',
#   'default': 'infer',
#   'description': '',
#   'type': 'string',
#   'unitsupport': False},
#  'InnerBoundaryVazi': {'choices': '',
#   'default': 'keplerian',
#   'description': '',
#   'type': 'string',
#   'unitsupport': False},
#  'InnerBoundaryVaziKeplerianFactor': {'choices': '',
#   'default': 1,
#   'description': '',
#   'type': 'double',
#   'unitsupport': False},
#  'InnerBoundaryVrad': {'choices': '',
#   'default': 'infer',
#   'description': '',
#   'type': 'string',
#   'unitsupport': False},
#  'InnerBoundaryVradKeplerianFactor': {'choices': '',
#   'default': 0.1,
#   'description': '',
#   'type': 'double',
#   'unitsupport': False},
#  'IntegrateParticles': {'choices': 'yes, no',
#   'default': False,
#   'description': 'Enable the particle module.',
#   'type': 'bool',
#   'unitsupport': False},
#  'IntegratePlanets': {'choices': 'yes, no',
#   'default': True,
#   'deprecated': True,
#   'description': 'Evolve the Nbody system.',
#   'newname': 'none'},
#  'Integrator': {'choices': 'Euler, LeapFrog',
#   'default': 'none',
#   'description': 'Select timestepping for hydro simulation: Euler or LeapFrog',
#   'type': 'string',
#   'unitsupport': False},
#  'KappaConst': {'choices': '',
#   'default': 1,
#   'description': '',
#   'type': 'double',
#   'unitsupport': False},
#  'KappaFactor': {'choices': '',
#   'default': 1,
#   'description': 'Fudge factor for kappa. Leave this as it is!',
#   'type': 'double',
#   'unitsupport': False},
#  'KeepDiskMassConstant': {'choices': 'yes, no',
#   'default': False,
#   'description': 'Rescale the mass of the disk periodically. You likely want to keep this turned off.',
#   'type': 'bool',
#   'unitsupport': False},
#  'KlahrSmoothingRadius': {'choices': '',
#   'default': 'none',
#   'description': 'Smoothing radius for Klahr & Kley smoothing around the secondary if H is calculated using all Nbody objects.',
#   'type': 'double',
#   'unitsupport': False},
#  'LogAfterRealSeconds': {'choices': 'positive integers',
#   'default': 'none',
#   'description': 'Write a log message to console after this number of real seconds. Setting to 0 disables this feature.',
#   'type': 'double',
#   'unitsupport': False},
#  'LogAfterSteps': {'choices': 'positive integers',
#   'default': 'none',
#   'description': 'Write a log message to console after this number hydro steps. Setting to 0 disables this feature.',
#   'type': 'unsigned int',
#   'unitsupport': False},
#  'MassAccretionRadius': {'choices': '',
#   'default': 'none',
#   'description': 'For inner boundary = boundary layer: Mass accretion radius in unints of R_hill / 2.',
#   'type': 'double',
#   'unitsupport': False},
#  'MassAccretionRate': {'choices': '',
#   'default': 1e-09,
#   'description': 'For inner boundary = boundary layer: Mass accretion rate (from secondary, young stellar cloud, etc.).',
#   'type': 'double',
#   'unitsupport': False},
#  'MaximumTemperature': {'choices': 'positive float w/wo unit',
#   'default': '1.0e300 K',
#   'description': 'Temperature ceiling.',
#   'type': 'double',
#   'unitsupport': False},
#  'MinimumTemperature': {'choices': 'positive float w/wo unit',
#   'default': '3 K',
#   'description': 'Temperature floor.',
#   'type': 'double',
#   'unitsupport': False},
#  'MonitorTimestep': {'choices': '',
#   'default': 'none',
#   'description': 'Calculate scalar quatities every MonitorTimestep in code units. For default units 2PI = 1 orbit at r=1',
#   'type': 'double',
#   'unitsupport': False},
#  'NSEC': {'choices': '',
#   'default': 64,
#   'deprecated': True,
#   'description': 'Number of azimuthal cells',
#   'newname': 'Naz'},
#  'NTOT': {'choices': '',
#   'default': 1000,
#   'deprecated': True,
#   'description': 'Number of snapshots to be written.',
#   'newname': 'Nsnapshots'},
#  'Naz': {'choices': '',
#   'default': 'none',
#   'description': '',
#   'type': 'unsigned int',
#   'unitsupport': False},
#  'Ninterm': {'choices': '',
#   'default': 'none',
#   'deprecated': True,
#   'description': 'Number of analysis outputs between two snapshots.',
#   'newname': 'Nmonitor',
#   'type': 'unsigned int',
#   'unitsupport': False},
#  'Nmonitor': {'choices': '',
#   'default': 'none',
#   'description': 'Number of monitor outputs between two snapshots.',
#   'oldname': 'Ninterm',
#   'type': 'unsigned int',
#   'unitsupport': False},
#  'Nrad': {'choices': '',
#   'default': 'none',
#   'description': 'Number of radial cells.',
#   'type': 'unsigned int',
#   'unitsupport': False},
#  'Nsnapshots': {'choices': '',
#   'default': 'none',
#   'description': 'Number of snapshots. The final time will be tfinal = Nsnapshots*Ninterm*MonitorTimestep. Please note that this is a different from FARGO3D!',
#   'type': 'unsigned int',
#   'unitsupport': False},
#  'NumberOfParticles': {'choices': '',
#   'default': 'none',
#   'description': 'Number of particles.',
#   'type': 'unsigned int',
#   'unitsupport': False},
#  'OmegaFrame': {'choices': '',
#   'default': 'none',
#   'description': 'Specify the angular velocity with which the frame rotates.',
#   'type': 'double',
#   'unitsupport': False},
#  'Opacity': {'choices': 'Lin, Bell, Zhu, Kramers',
#   'default': 'none',
#   'description': 'Opacity table to use.',
#   'type': 'string',
#   'unitsupport': False},
#  'OuterBoundary': {'choices': 'Open, Reflective/Rigid, ZeroGradient, PrescribedTimeVariable, BoundaryLayer',
#   'default': 'none',
#   'description': 'Boundary condition at the outer boundary.',
#   'type': 'string',
#   'unitsupport': False},
#  'OuterBoundaryEnergy': {'choices': '',
#   'default': 'infer',
#   'description': '',
#   'type': 'string',
#   'unitsupport': False},
#  'OuterBoundarySigma': {'choices': '',
#   'default': 'infer',
#   'description': '',
#   'type': 'string',
#   'unitsupport': False},
#  'OuterBoundaryVazi': {'choices': '',
#   'default': 'keplerian',
#   'description': '',
#   'type': 'string',
#   'unitsupport': False},
#  'OuterBoundaryVaziKeplerianFactor': {'choices': '',
#   'default': 1,
#   'description': '',
#   'type': 'double',
#   'unitsupport': False},
#  'OuterBoundaryVrad': {'choices': '',
#   'default': 'infer',
#   'description': '',
#   'type': 'string',
#   'unitsupport': False},
#  'OuterBoundaryVradKeplerianFactor': {'choices': '',
#   'default': 0.1,
#   'description': '',
#   'type': 'double',
#   'unitsupport': False},
#  'OuterSourceMass': {'choices': '',
#   'default': False,
#   'description': '?',
#   'type': 'bool',
#   'unitsupport': False},
#  'OutputDir': {'choices': '',
#   'default': 'none',
#   'description': 'Specify the output directory.',
#   'type': 'string',
#   'unitsupport': False},
#  'ParticleDensity': {'choices': '',
#   'default': '2.65 g/cm3',
#   'description': 'Particle material density. [default = 2.65, Siliciumdioxid].',
#   'type': 'double',
#   'unitsupport': False},
#  'ParticleDiskGravityEnabled': {'choices': '',
#   'default': False,
#   'description': 'Enable disk self-gravity acting on particles. TODO: this should be set to default to reflect the self-gravity flag.',
#   'type': 'bool',
#   'unitsupport': False},
#  'ParticleDustDiffusion': {'choices': '',
#   'default': False,
#   'description': 'Enable dust diffusion.',
#   'type': 'bool',
#   'unitsupport': False},
#  'ParticleEccentricity': {'choices': '',
#   'default': 'none',
#   'description': 'Initialize the particles with eccentricities drawn from a uniform random distribution between 0 and this number.',
#   'type': 'double',
#   'unitsupport': False},
#  'ParticleGasDragEnabled': {'choices': '',
#   'default': True,
#   'description': 'Enable particle gas drag.',
#   'type': 'bool',
#   'unitsupport': False},
#  'ParticleIntegrator': {'choices': 'e, m',
#   'default': 'none',
#   'description': 'Select the particle integrator. Explicit (Cash-Carp with adaptive timesteping), Midpoint (Mignone 2019)',
#   'type': 'string',
#   'unitsupport': False},
#  'ParticleMaximumEscapeRadius': {'choices': '',
#   'default': 2.5,
#   'description': 'Eject particles that move outside this radius. [default = ParticleMaximumRadius]',
#   'type': 'double',
#   'unitsupport': False},
#  'ParticleMaximumRadius': {'choices': '',
#   'default': 2.5,
#   'description': 'Initialize particles up to this radius. [default = RMAX]',
#   'type': 'double',
#   'unitsupport': False},
#  'ParticleMinimumEscapeRadius': {'choices': '',
#   'default': 0.4,
#   'description': 'Eject particles that move inside this radius. [default = ParticleMinimumRadius]',
#   'type': 'double',
#   'unitsupport': False},
#  'ParticleMinimumRadius': {'choices': '',
#   'default': 0.4,
#   'description': 'Initialize particles starting at this radius. [default = RMIN]',
#   'type': 'double',
#   'unitsupport': False},
#  'ParticleRadius': {'choices': '',
#   'default': '100.0 cm',
#   'description': 'Particle radius in cm [default = 100] TODO: change default radius to 1cm',
#   'type': 'double',
#   'unitsupport': False},
#  'ParticleRadiusIncreaseFactor': {'choices': '',
#   'default': 'none',
#   'description': 'Increase the size of each particle species by this factor. The size of the nth particle species is then ParticleRadius*IncreaseFactor^{n-1}.',
#   'type': 'double',
#   'unitsupport': False},
#  'ParticleSpeciesNumber': {'choices': '',
#   'default': 'none',
#   'description': 'Number of particle species/sizes.',
#   'type': 'unsigned int',
#   'unitsupport': False},
#  'ParticleSurfaceDensitySlope': {'choices': '',
#   'default': 'none',
#   'description': 'Slope of particle surface density distribution: Sigma(r) = Sigma0 * r^(-ParticleSurfaceDensitySlope). [default = SigmaSlope]',
#   'type': 'double',
#   'unitsupport': False},
#  'PlanetOrbitDiskTest': {'choices': '',
#   'default': False,
#   'description': 'Enable test mode for a planet orbiting around just a disk.',
#   'type': 'bool',
#   'unitsupport': False},
#  'PolytropicConstant': {'choices': 'positive value',
#   'default': 12.753,
#   'description': 'Set the polytropic constant for the polytropic equation of state.',
#   'type': 'string',
#   'unitsupport': False},
#  'ProfileCutoffInner': {'choices': '',
#   'default': False,
#   'description': 'Enable exponential cutoff for the density profile at the inner boundary.',
#   'type': 'bool',
#   'unitsupport': False},
#  'ProfileCutoffOuter': {'choices': '',
#   'default': False,
#   'description': 'Enable exponential cutoff for the density profile at the outer boundary.',
#   'type': 'bool',
#   'unitsupport': False},
#  'ProfileCutoffPointInner': {'choices': '',
#   'default': 0,
#   'description': 'Location of the cuttoff at the inner boundary.',
#   'type': 'double',
#   'unitsupport': False},
#  'ProfileCutoffPointOuter': {'choices': '',
#   'default': 1e+300,
#   'description': 'Location of the cuttoff at the outer boundary.',
#   'type': 'double',
#   'unitsupport': False},
#  'ProfileCutoffWidthInner': {'choices': '',
#   'default': 1,
#   'description': 'Width of the cutoff at the inner boundary.',
#   'type': 'double',
#   'unitsupport': False},
#  'ProfileCutoffWidthOuter': {'choices': '',
#   'default': 1,
#   'description': 'Width of the cutoff at the outer boundary.',
#   'type': 'double',
#   'unitsupport': False},
#  'QuantitiesRadiusLimit': {'choices': '',
#   'default': 5,
#   'description': 'Limit the calculation of disk quantities to inside this radius. TODO: enlarge radius',
#   'type': 'double',
#   'unitsupport': False},
#  'ROFVariableTransfer': {'choices': '',
#   'default': False,
#   'description': '',
#   'type': 'bool',
#   'unitsupport': False},
#  'ROFaveragingtime': {'choices': '',
#   'default': 10,
#   'description': '',
#   'type': 'double',
#   'unitsupport': False},
#  'ROFgamma': {'choices': '',
#   'default': 0.5,
#   'description': '',
#   'type': 'double',
#   'unitsupport': False},
#  'ROFplanet': {'choices': '',
#   'default': 1,
#   'description': '',
#   'type': 'int',
#   'unitsupport': False},
#  'ROFrampingtime': {'choices': '',
#   'default': 30,
#   'description': '',
#   'type': 'double',
#   'unitsupport': False},
#  'ROFtemperature': {'choices': '',
#   'default': '1000.0 K',
#   'description': '',
#   'type': 'double',
#   'unitsupport': False},
#  'ROFvalue': {'choices': '',
#   'default': '1e-08',
#   'description': '',
#   'type': 'double',
#   'unitsupport': False},
#  'RadialSpacing': {'choices': 'Logarithmic or ARITHMETIC or Exponential',
#   'default': 'none',
#   'description': 'Type of the radial grid spacing.',
#   'type': 'string',
#   'unitsupport': False},
#  'RadialViscosityFactor': {'choices': '',
#   'default': 1,
#   'description': 'Viscosity in radial direction is mutliplied with this factor to avoid oscillations.',
#   'type': 'double',
#   'unitsupport': False},
#  'RadiativeDiffusion': {'choices': 'yes, no',
#   'default': False,
#   'description': 'Turn on 2D FLD to simulate radiative transport in the midplane.',
#   'type': 'bool',
#   'unitsupport': False},
#  'RadiativeDiffusionAutoOmega': {'choices': '',
#   'default': False,
#   'description': 'Automatically update SOR Omega. Needs testing. Do not set to yes.',
#   'type': 'bool',
#   'unitsupport': False},
#  'RadiativeDiffusionCheckSolution': {'choices': '',
#   'default': False,
#   'description': '',
#   'type': 'bool',
#   'unitsupport': False},
#  'RadiativeDiffusionDumpData': {'choices': '',
#   'default': False,
#   'description': '',
#   'type': 'bool',
#   'unitsupport': False},
#  'RadiativeDiffusionInnerBoundary': {'choices': '',
#   'default': 'none',
#   'description': '',
#   'type': 'string',
#   'unitsupport': False},
#  'RadiativeDiffusionMaxIterations': {'choices': '',
#   'default': 'none',
#   'description': 'Maximum number of SOR iterations for FLD.',
#   'type': 'unsigned int',
#   'unitsupport': False},
#  'RadiativeDiffusionOmega': {'choices': '',
#   'default': 'none',
#   'description': 'Parameter for the succesive-overrelaxation (SOR) solver for the linear system of the FLD radiative transport.',
#   'type': 'double',
#   'unitsupport': False},
#  'RadiativeDiffusionOuterBoundary': {'choices': '',
#   'default': 'none',
#   'description': '',
#   'type': 'string',
#   'unitsupport': False},
#  'RadiativeDiffusionTest1D': {'choices': '',
#   'default': False,
#   'description': '',
#   'type': 'bool',
#   'unitsupport': False},
#  'RadiativeDiffusionTest2D': {'choices': '',
#   'default': False,
#   'description': '',
#   'type': 'bool',
#   'unitsupport': False},
#  'RadiativeDiffusionTest2DDensity': {'choices': '',
#   'default': '1.0 g/cm3',
#   'description': '',
#   'type': 'double',
#   'unitsupport': False},
#  'RadiativeDiffusionTest2DK': {'choices': '',
#   'default': 1,
#   'description': '',
#   'type': 'double',
#   'unitsupport': False},
#  'RadiativeDiffusionTest2DSteps': {'choices': '',
#   'default': 1,
#   'description': '',
#   'type': 'unsigned int',
#   'unitsupport': False},
#  'RadiativeDiffusionTolerance': {'choices': '',
#   'default': '1e-10',
#   'description': '',
#   'type': 'double',
#   'unitsupport': False},
#  'RandomFactor': {'choices': '',
#   'default': 'none',
#   'description': 'Randomize by +- 10%',
#   'type': 'double',
#   'unitsupport': False},
#  'RandomSeed': {'choices': '',
#   'default': 'none',
#   'description': 'Random seed integer value for noise on initial profile.',
#   'type': 'int',
#   'unitsupport': False},
#  'RandomSigma': {'choices': 'yes, no',
#   'default': False,
#   'description': 'Put random noise on surface density at start values.',
#   'type': 'bool',
#   'unitsupport': False},
#  'Rmax': {'choices': '',
#   'default': 'none',
#   'description': '',
#   'type': 'double',
#   'unitsupport': False},
#  'Rmin': {'choices': '',
#   'default': 'none',
#   'description': '',
#   'type': 'double',
#   'unitsupport': False},
#  'RocheLobeOverflow': {'choices': '',
#   'default': False,
#   'description': '',
#   'type': 'bool',
#   'unitsupport': False},
#  'ScurveType': {'choices': '',
#   'default': 'none',
#   'description': '',
#   'type': 'string',
#   'unitsupport': False},
#  'SecondaryDisk': {'choices': 'yes, no',
#   'default': False,
#   'description': 'Initialize a secondary disk. This is used for binary star systems.',
#   'type': 'bool',
#   'unitsupport': False},
#  'SelfGravity': {'choices': 'Yes, Z, No',
#   'default': False,
#   'description': 'Enable self-gravity. This uses the Fourier-Convolution technique from Clement Baruteau with a modification for the scale height by Tobias Modlenhauer to make the accelerations symmetric.',
#   'type': 'bool',
#   'unitsupport': False},
#  'SelfGravityAspectRatioChangeThreshold': {'choices': '',
#   'default': 0.001,
#   'description': '',
#   'type': 'double',
#   'unitsupport': False},
#  'SelfGravityMode': {'choices': '',
#   'default': 'besselkernel',
#   'description': '',
#   'type': 'string',
#   'unitsupport': False},
#  'SelfGravityStepsBetweenKernelUpdate': {'choices': '',
#   'default': 20,
#   'description': '',
#   'type': 'unsigned int',
#   'unitsupport': False},
#  'SetSigma0': {'choices': 'yes, no',
#   'default': False,
#   'description': 'Renormalize Sigma0 to have M_disc = discmass in units.',
#   'type': 'bool',
#   'unitsupport': False},
#  'ShockTube': {'choices': '0, 1, 2',
#   'default': 0,
#   'description': 'Initialize shocktube problem with 0:no shocktube 1:Ideal EOS (perfect gas) 2: PVTE EOS (variableGamma)',
#   'type': 'int',
#   'unitsupport': False},
#  'Sigma0': {'choices': '',
#   'default': '173 g/cm2',
#   'description': 'Set the scale for the Surface density profile: Sigma = Sigma0 * r^-SigmaSlope. TODO: change to value with unit.',
#   'type': 'double',
#   'unitsupport': False},
#  'SigmaCondition': {'choices': 'Profile, 1D, 2D',
#   'default': 'Profile',
#   'description': 'Initialize surface density by Profile, 1D data file or 2D data file.',
#   'type': 'string',
#   'unitsupport': False},
#  'SigmaFilename': {'choices': '',
#   'default': '',
#   'description': 'File to read surface density from (when Condition = 1D or 2D)',
#   'type': 'string',
#   'unitsupport': False},
#  'SigmaFloor': {'choices': '',
#   'default': 'none',
#   'description': 'Floor surface density in multiples of sigma0.',
#   'type': 'double',
#   'unitsupport': False},
#  'SigmaSlope': {'choices': 'float',
#   'default': 'none',
#   'description': 'Powerlaw exponent (the nagative of it) of the initial surface density profile. Sigma = Sigma0 * r^-SigmaSlope.',
#   'type': 'double',
#   'unitsupport': False},
#  'SpreadingRing': {'choices': 'yes, no',
#   'default': False,
#   'description': 'Initialize the simulation with the spreading ring test case.',
#   'type': 'bool',
#   'unitsupport': False},
#  'StabilizeArtViscosity': {'choices': '',
#   'default': 0,
#   'description': 'Artificially stabalize artificial viscosity to avoid numerical issues.',
#   'type': 'double',
#   'unitsupport': False},
#  'StabilizeViscosity': {'choices': '',
#   'default': 0,
#   'description': 'Artificially stabalize viscosity to avoid numerical issues.',
#   'type': 'int',
#   'unitsupport': False},
#  'StarRadius': {'choices': 'positive value',
#   'deprecated': True,
#   'description': 'Radius of the star used together with StarTemperature for computing the flux.',
#   'hint': "Use key 'radius' for Nbody objects.",
#   'newname': 'none',
#   'type': 'double',
#   'unitsupport': False},
#  'StarTemperature': {'choices': 'positive value',
#   'deprecated': True,
#   'description': 'Radius of the star used together with StarRadius for computing the flux.',
#   'hint': "Use key 'temperature' for Nbody objects.",
#   'newname': 'none',
#   'type': 'double',
#   'unitsupport': False},
#  'StellarRotation': {'choices': '',
#   'default': 0.1,
#   'deprecated': True,
#   'description': 'For inner boundary = boundary layer: Stellar rotation rate (azimuthal velocity of the surface) in terms of Keplerian angular velocity at the inner boundary.',
#   'hint': 'InnerBoundaryVaziKeplerianFactor, InnerBoundaryVazi = keplerian',
#   'newname': 'none'},
#  'StsNu': {'choices': 'positive value',
#   'default': '0.01',
#   'deprecated': True,
#   'description': 'Set the value of the viscosity for the STS module.',
#   'hint': 'The STS module has been removed.',
#   'newname': 'none',
#   'type': 'double',
#   'unitsupport': False},
#  'SurfaceCooling': {'choices': '',
#   'default': 'none',
#   'description': '',
#   'type': 'string',
#   'unitsupport': False},
#  'TauFactor': {'choices': '',
#   'default': 0.5,
#   'description': 'Fudge factor for tau. Leave this as it is! [default = 1.0] TODO: change default value.',
#   'type': 'double',
#   'unitsupport': False},
#  'TauMin': {'choices': '',
#   'default': 0.01,
#   'description': 'Tau min for the effective optical depth calculation. See Hubney (1990), Mueller & Kley (2012) and DAngelo & Marzari (2015).',
#   'type': 'double',
#   'unitsupport': False},
#  'Temperature0': {'choices': '',
#   'default': -1,
#   'description': 'If > 0, set the reference temperature at l0 instead of using the reference aspect ratio.',
#   'type': 'double',
#   'unitsupport': False},
#  'Temperaturecgs0': {'choices': 'positive value',
#   'default': 'none',
#   'deprecated': True,
#   'description': 'Set the reference temperature in cgs units.',
#   'hint': "Use Temperature0 instead. Append a 'K' to the value to set the temperature in Kelvin.",
#   'newname': 'none',
#   'type': 'double',
#   'unitsupport': False},
#  'ThicknessSmoothing': {'choices': '',
#   'default': 'none',
#   'description': 'Smoothing/softening parameters for the Nbody-disk gravitional interaction in multiples of the disk scaleheight.',
#   'type': 'double',
#   'unitsupport': False},
#  'ThicknessSmoothingSG': {'choices': '',
#   'default': 'none',
#   'description': 'Smoothing/softening parameter for SG [default = ThicknessSmoothing] TODO: change the default to thickness smoothing',
#   'type': 'double',
#   'unitsupport': False},
#  'Transport': {'choices': 'fast, slow',
#   'default': 'none',
#   'description': 'Specify whether or not to use the Fargo method (fast) or the standard method (slow).',
#   'type': 'string',
#   'unitsupport': False},
#  'VISCOSITY': {'choices': '',
#   'default': 0,
#   'deprecated': True,
#   'description': 'Set a constant kinetic viscosity.',
#   'newname': 'ConstantViscosity'},
#  'VRadIn': {'choices': '',
#   'default': 0.0016,
#   'deprecated': True,
#   'description': 'For inner boundary = boundary layer: value of v_rad at inner boundary in terms of Keplerian velocity v_kepler at the inner boundary.',
#   'hint': 'InnerBoundaryVradKeplerianFactor, InnerBoundaryVrad = keplerian',
#   'newname': 'none'},
#  'VazimuthalConsidersQuadropoleMoment': {'choices': 'yes, no',
#   'default': False,
#   'description': 'Add quadropole moment support in initialization of azimuthal velocity.',
#   'type': 'bool',
#   'unitsupport': False},
#  'ViscAccretMassflowTest': {'choices': '',
#   'default': False,
#   'description': 'Enable viscous accretion massflow test.',
#   'type': 'bool',
#   'unitsupport': False},
#  'ViscosityInCGS': {'choices': 'yes, no',
#   'default': False,
#   'deprecated': True,
#   'description': 'Interpret the value of constant viscosity to be in cgs.',
#   'hint': "Use the 'ConstantViscosity' key instead. It supports specifying units.",
#   'newname': 'none',
#   'type': 'bool',
#   'unitsupport': False},
#  'ViscousAlpha': {'choices': '',
#   'default': 'none',
#   'description': 'Specify the value of alpha for the alpha viscosity model.',
#   'oldname': 'AlphaViscosity',
#   'type': 'double',
#   'unitsupport': False},
#  'ViscousOutflowSpeed': {'choices': 'positive float',
#   'default': 1,
#   'description': '# Viscous outflow speed vr(0) = -3/2 nu / R(0) * ViscousOutflowSpeed used for VISC boundary condition and inside viscous accretion.',
#   'type': 'double',
#   'unitsupport': False},
#  'WriteAlpha': {'choices': 'yes, no',
#   'default': False,
#   'description': 'Write 2D data of viscous alpha.',
#   'type': 'bool',
#   'unitsupport': False},
#  'WriteAlphaGrav': {'choices': 'yes, no',
#   'default': False,
#   'description': 'Write 2D array of alpha value gravitational strees.',
#   'type': 'bool',
#   'unitsupport': False},
#  'WriteAlphaGravMean': {'choices': 'yes, no',
#   'default': False,
#   'description': 'Write 2D array of azimuthal mean of the alpha value of gravitational stress.',
#   'type': 'bool',
#   'unitsupport': False},
#  'WriteAlphaReynolds': {'choices': 'yes, no',
#   'default': False,
#   'description': 'Write 2D array of alpha value Reynolds strees.',
#   'type': 'bool',
#   'unitsupport': False},
#  'WriteAlphaReynoldsMean': {'choices': 'yes, no',
#   'default': False,
#   'description': 'Write 2D array of azimuthal mean of the alpha value of Reynolds stress.',
#   'type': 'bool',
#   'unitsupport': False},
#  'WriteAspectratio': {'choices': 'yes, no',
#   'default': False,
#   'description': 'Write 2D array of the aspect ratio.',
#   'type': 'bool',
#   'unitsupport': False},
#  'WriteAtEveryTimestep': {'choices': 'yes, no',
#   'default': True,
#   'description': 'Write some quantities (planet positions, disk quantities, ...) at every Timestep.',
#   'type': 'bool',
#   'unitsupport': False},
#  'WriteDefaultValues': {'choices': 'yes, no',
#   'default': False,
#   'description': 'Write a yaml file to the output directory containing all default values hardcoded in the code.',
#   'type': 'bool',
#   'unitsupport': False},
#  'WriteDensity': {'choices': 'yes, no',
#   'default': True,
#   'description': 'Write surface density. This is needed for restart of simulations.',
#   'type': 'bool',
#   'unitsupport': False},
#  'WriteDiskQuantities': {'choices': 'yes, no',
#   'default': True,
#   'description': 'Write a collection of disk quantities (mass, eccentricity, periastron, semi_major_axis, ...)',
#   'type': 'bool',
#   'unitsupport': False},
#  'WriteDivV': {'choices': 'yes, no',
#   'default': False,
#   'description': 'Write 2D array of divergence of velocity.',
#   'type': 'bool',
#   'unitsupport': False},
#  'WriteEccentricity': {'choices': 'yes, no',
#   'default': False,
#   'description': 'Write 2D array of eccentricity based on specific angular momentum of the cell.',
#   'type': 'bool',
#   'unitsupport': False},
#  'WriteEccentricityChange': {'choices': '',
#   'default': False,
#   'description': 'Eccentricity change monitor.',
#   'type': 'bool',
#   'unitsupport': False},
#  'WriteEffectiveGamma': {'choices': 'yes, no',
#   'default': False,
#   'description': 'Write 2D effective adiabatic index.',
#   'type': 'bool',
#   'unitsupport': False},
#  'WriteEnergy': {'choices': 'yes, no',
#   'default': True,
#   'description': 'Write energy. This is needed for restart of (adiabatic) simulations.',
#   'type': 'bool',
#   'unitsupport': False},
#  'WriteFirstAdiabaticIndex': {'choices': 'yes, no',
#   'default': False,
#   'description': 'Write 2D data of the first adiabatic index. Usefull for PVTE EoS.',
#   'type': 'bool',
#   'unitsupport': False},
#  'WriteGasTorques': {'choices': 'yes, no',
#   'default': False,
#   'description': 'Calculate and write gravitational/viscous and advection torques on gas. See Miranda et al. 2017',
#   'type': 'bool',
#   'unitsupport': False},
#  'WriteKappa': {'choices': 'yes, no',
#   'default': False,
#   'description': 'Write 2D array of opacity.',
#   'type': 'bool',
#   'unitsupport': False},
#  'WriteLightCurves': {'choices': 'yes, no',
#   'default': False,
#   'description': 'Write light curves.',
#   'type': 'bool',
#   'unitsupport': False},
#  'WriteLightCurvesRadii': {'choices': '',
#   'default': 'none',
#   'description': '',
#   'type': 'string',
#   'unitsupport': False},
#  'WriteMassFlow': {'choices': 'yes, no',
#   'default': False,
#   'description': 'Write a 1D radial file with mass flow at each interface. Track accretion through the disk.',
#   'type': 'bool',
#   'unitsupport': False},
#  'WriteMeanMolecularWeight': {'choices': 'yes, no',
#   'default': False,
#   'description': 'Write 2D data of mean molecular weight.',
#   'type': 'bool',
#   'unitsupport': False},
#  'WritePotential': {'choices': 'yes, no',
#   'default': False,
#   'description': 'Write 2D array of the gravitational potential.',
#   'type': 'bool',
#   'unitsupport': False},
#  'WritePressure': {'choices': 'yes, no',
#   'default': False,
#   'description': 'Write 2D array of pressure.',
#   'type': 'bool',
#   'unitsupport': False},
#  'WriteQMinus': {'choices': 'yes, no',
#   'default': False,
#   'description': 'Write 2D array of cooling terms.',
#   'type': 'bool',
#   'unitsupport': False},
#  'WriteQPlus': {'choices': 'yes, no',
#   'default': False,
#   'description': 'Write 2D array of heating terms.',
#   'type': 'bool',
#   'unitsupport': False},
#  'WriteRadialDissipation': {'choices': 'yes, no',
#   'default': False,
#   'description': 'Write 1D raidal array of dissipated energy.',
#   'type': 'bool',
#   'unitsupport': False},
#  'WriteRadialLuminosity': {'choices': 'yes, no',
#   'default': False,
#   'description': 'Write 1D radial array of luminosity.',
#   'type': 'bool',
#   'unitsupport': False},
#  'WriteSGAccelAzi': {'choices': '',
#   'default': False,
#   'description': '',
#   'type': 'bool',
#   'unitsupport': False},
#  'WriteSGAccelRad': {'choices': '',
#   'default': False,
#   'description': '',
#   'type': 'bool',
#   'unitsupport': False},
#  'WriteScaleHeight': {'choices': "yes, no'",
#   'default': False,
#   'description': 'Write 2D array of the scale height.',
#   'type': 'bool',
#   'unitsupport': False},
#  'WriteSoundSpeed': {'choices': 'yes, no',
#   'default': False,
#   'description': 'Write 2D sound speed.',
#   'type': 'bool',
#   'unitsupport': False},
#  'WriteTGravitational': {'choices': '',
#   'default': False,
#   'description': 'Write 2D array of the gravitational stress.',
#   'type': 'bool',
#   'unitsupport': False},
#  'WriteTReynolds': {'choices': 'yes, no',
#   'default': False,
#   'description': 'Write 2D array of the Reynolds stress.',
#   'type': 'bool',
#   'unitsupport': False},
#  'WriteTau': {'choices': 'yes, no',
#   'default': False,
#   'description': 'Write 2D array of optical depth.',
#   'type': 'bool',
#   'unitsupport': False},
#  'WriteTauCool': {'choices': 'yes, no',
#   'default': False,
#   'description': 'Write 2D array of optical depth for cooling.',
#   'type': 'bool',
#   'unitsupport': False},
#  'WriteTemperature': {'choices': 'yes, no',
#   'default': False,
#   'description': 'Write 2D temperature.',
#   'type': 'bool',
#   'unitsupport': False},
#  'WriteToomre': {'choices': 'yes, no',
#   'default': False,
#   'description': 'Write 2D array of Toomre parameter Q.',
#   'type': 'bool',
#   'unitsupport': False},
#  'WriteTorques': {'choices': '',
#   'default': False,
#   'description': 'Calculate and write 2D array of torques acting on each planet/star.',
#   'type': 'bool',
#   'unitsupport': False},
#  'WriteVelocity': {'choices': 'yes, no',
#   'default': True,
#   'description': 'Write velocites. This is needed for restart of simulations.',
#   'type': 'bool',
#   'unitsupport': False},
#  'WriteVerticalOpticalDepth': {'choices': '',
#   'default': False,
#   'description': 'Write 2D of optical depth in vertical direction (tau_eff by Hubeny [1990]).',
#   'type': 'bool',
#   'unitsupport': False},
#  'WriteViscosity': {'choices': 'yes, no',
#   'default': False,
#   'description': 'Write 2D array of the kinematic viscosity.',
#   'type': 'bool',
#   'unitsupport': False},
#  'WriteVisibility': {'choices': 'yes, no',
#   'default': False,
#   'description': 'Write 2D array of visibility.',
#   'type': 'bool',
#   'unitsupport': False},
#  'WritepDV': {'choices': 'yes, no',
#   'default': False,
#   'description': 'Write 2D array of pressure * divergence of v.',
#   'type': 'bool',
#   'unitsupport': False},
#  'cps': {'choices': '',
#   'default': 'none',
#   'description': 'Set the resolution in terms of cells per scaleheight ar r=1: if cps > 0, overrides Nrad and Nsec and initializes them according to domain size and AspectRatio.',
#   'type': 'double',
#   'unitsupport': False},
#  'discmass': {'choices': '',
#   'default': 0.01,
#   'deprecated': True,
#   'description': 'In case of SetSigma0=yes, use this mass as diskmass.',
#   'newname': 'DiskMass'},
#  'l0': {'choices': '',
#   'default': 'none',
#   'description': 'Base length unit of the simulation [default: 1.0 au]',
#   'type': 'string',
#   'unitsupport': False},
#  'm0': {'choices': '',
#   'default': 'none',
#   'description': 'Base mass unit of the simulation [default: 1.0 solMass]',
#   'type': 'string',
#   'unitsupport': False},
#  'massoverflow': {'choices': 'yes, no',
#   'default': False,
#   'deprecated': True,
#   'description': 'Enable a constant massflow coming though the outer boundary.',
#   'newname': 'RocheLobeOverflow'},
#  'mofaveragingtime': {'choices': '',
#   'default': 10,
#   'deprecated': True,
#   'description': '?',
#   'newname': 'ROFAveragingTime'},
#  'mofgamma': {'choices': '',
#   'default': 0.5,
#   'deprecated': True,
#   'description': '?',
#   'newname': 'ROFGamma'},
#  'mofplanet': {'choices': '',
#   'default': 1,
#   'deprecated': True,
#   'description': '?',
#   'newname': 'ROFPlanet'},
#  'moframpingtime': {'choices': '',
#   'default': 30,
#   'deprecated': True,
#   'description': 'Gradual increase for the mass overflow.',
#   'newname': 'ROFRampingTime'},
#  'moftemperature': {'choices': '',
#   'default': '1000.0 K',
#   'deprecated': True,
#   'description': '?',
#   'newname': 'ROFTemperature'},
#  'mofvalue': {'choices': '',
#   'default': '1e-08',
#   'deprecated': True,
#   'description': '?',
#   'newname': 'ROFValue'},
#  'mu': {'choices': 'positive float',
#   'default': 'none',
#   'description': 'Mean molecular weight of the gas. TODO: change default value.',
#   'type': 'double',
#   'unitsupport': False},
#  't0': {'choices': '',
#   'default': 1.0,
#   'description': '',
#   'type': 'string',
#   'unitsupport': False},
#  'temp0': {'choices': '',
#   'default': 1.0,
#   'description': '',
#   'type': 'string',
#   'unitsupport': False},
#  'variableTransfer': {'choices': '',
#   'default': False,
#   'deprecated': True,
#   'description': '?',
#   'newname': 'ROFVariableTransfer'},
#  'zbufferMaxAngle': {'choices': '',
#   'default': 0.17453292519943295,
#   'deprecated': True,
#   'description': '',
#   'newname': 'none'},
#  'zbufferSize': {'choices': '',
#   'default': 100,
#   'deprecated': True,
#   'description': '',
#   'newname': 'none'}}

# %%
defaultfile = "output/out/default_config.yml"

with open(defaultfile, "r") as infile:
    defaults = yaml.safe_load(infile)

# clean up types
for key, val in defaults.items():
    t = val["type"]
    if "basic_string" in t:
        t = "string"
    elif t == "d":
        t = "double"
    elif t == "i":
        t = "int"
    elif t == "b":
        t = "bool"
    elif t == "j":
        t = "unsigned int"
    val["type"] = t

# %%
defaults["AdiabaticIndex"]
# Out:
# {'default': 1.4, 'type': 'bool', 'unitsupport': False}

# %%
# add deprecated flag to parameters that are not in the default file
lkeys_to_remove = []
param_old_lkeys = {key.lower() : key for key in parameters}
default_lkeys = {key.lower() : key for key in defaults}
for key in parameters:
    lkey = key.lower()
    if not lkey in default_lkeys:
        lkeys_to_remove.append(key)
for key in lkeys_to_remove:
    key = param_old_lkeys[key.lower()]
    parameters[key]["deprecated"] = True

new_params = {}

for key in defaults:
    lkey = key.lower()
    # copy the old param dict to an entry with new capitalization
    if lkey in param_old_lkeys:
        oldkey = param_old_lkeys[lkey]
        new_params[key] = parameters[oldkey]


    desc = ""
    try:
        defvalue = defaults[key]["default"]
    except KeyError:
        defvalue = "none"
    # add new parameters
    if not key in new_params:
        new_params[key] = {
            "default" : defvalue,
            "description" : desc,
            "choices" : ""
        }

    # update types
    new_params[key]["type"] = defaults[key]["type"]
    # update unitsupport
    if "unitsupport" in defaults[key]:
        new_params[key]["unitsupport"] = defaults[key]["unitsupport"]
    # manually overwrite unit support for base units
    if key in ["l0", "m0", "temp0", "t0"]:
        new_params[key]["unitsupport"] = True
    # update default values
    if new_params[key]["default"] != defvalue:
        new_params[key]["default"] = defvalue

# copy left over deprecated parameters
for key, val in parameters.items():
    if "deprecated" in parameters[key]:
        new_params[key] = parameters[key]

# %%
deprecated_params = {}
for key, val in new_params.items():
    if "deprecated" in val:
        deprecated_params[key] = val
        print(key, val)
# Out:
# Adiabatic {'choices': '', 'default': False, 'deprecated': True, 'description': 'Deprecated. Dont use this anymore.', 'hint': 'EquationOfState: Ideal', 'newname': 'none', 'type': 'bool', 'unitsupport': False}
# ALPHAVISCOSITY {'choices': '', 'default': 0, 'deprecated': True, 'description': 'Specify the value of alpha for the alpha viscosity model.', 'newname': 'ViscousAlpha'}
# AlphaThreshold {'choices': 'positive values', 'default': 5000, 'deprecated': True, 'description': '?Threshold value for viscosity stabalized?', 'newname': 'none', 'type': 'double', 'unitsupport': False}
# CoolingRadiativeLocal {'choices': 'yes, no', 'default': False, 'deprecated': True, 'description': 'Enable local radiative cooling Q- = 2 * sigma_R * T_eff^4.', 'hint': 'SurfaceCooling: thermal', 'newname': 'none'}
# CoolingScurve {'choices': 'yes, no', 'default': False, 'deprecated': True, 'description': 'Enable Scurve Cooling', 'hint': 'SurfaceCooling: scurve', 'newname': 'none'}
# DT {'choices': '', 'default': 1, 'deprecated': True, 'description': 'Time between two analysis outputs. For default units, 2PI = 1 orbit at r=1.', 'newname': 'MonitorTimestep'}
# DebugOutputs {'choices': 'yes, no', 'default': False, 'deprecated': True, 'description': 'Write out additional debug files.', 'newname': 'none', 'type': 'bool', 'unitsupport': False}
# DomegaDrZero {'choices': 'yes, no', 'default': False, 'deprecated': True, 'description': 'Set dOmega/dr = 0 at outer boundary', 'hint': 'OuterBoundaryAzi = zeroshear', 'newname': 'none'}
# ExplicitViscosity {'choices': 'yes, no', 'default': False, 'deprecated': True, 'description': 'Consider explicit viscocsity.', 'hint': 'Set ViscousAlpha > 0 or ConstantViscosity > 0', 'newname': 'none', 'type': 'bool', 'unitsupport': False}
# ForcedCircular {'choices': 'yes, no', 'default': False, 'deprecated': True, 'description': 'Keep the eccentricity of the planet to zero. [default = no]', 'newname': 'none', 'type': 'bool', 'unitsupport': False}
# HeatingStar {'choices': 'yes, no', 'default': False, 'deprecated': True, 'description': 'Enable irradiation heating by the star.', 'hint': 'Set temperature of any Nbody object > 0 to enable irradiation from this object.', 'newname': 'none', 'type': 'bool', 'unitsupport': False}
# HeatingStarFactor {'choices': 'positive value', 'deprecated': True, 'description': 'Modulate the heating by this factor.', 'hint': 'Change the temperature of the Nbody object to modulate the heating.', 'newname': 'none', 'type': 'double', 'unitsupport': False}
# HeatingStarRampingTime {'choices': 'positive value', 'deprecated': True, 'description': 'Ramp up the heating over this time.', 'hint': "Use key 'irradiation ramp-up time' for Nbody objects.", 'newname': 'none', 'type': 'double', 'unitsupport': False}
# HeatingStarSimple {'choices': 'yes, no', 'default': False, 'deprecated': True, 'description': 'Enable simple irradiation heating by the star solely based on distance.', 'hint': 'This is now the only option.', 'newname': 'none', 'type': 'bool', 'unitsupport': False}
# IntegratePlanets {'choices': 'yes, no', 'default': True, 'deprecated': True, 'description': 'Evolve the Nbody system.', 'newname': 'none'}
# NSEC {'choices': '', 'default': 64, 'deprecated': True, 'description': 'Number of azimuthal cells', 'newname': 'Naz'}
# NTOT {'choices': '', 'default': 1000, 'deprecated': True, 'description': 'Number of snapshots to be written.', 'newname': 'Nsnapshots'}
# Ninterm {'choices': '', 'default': 'none', 'deprecated': True, 'description': 'Number of analysis outputs between two snapshots.', 'newname': 'Nmonitor', 'type': 'unsigned int', 'unitsupport': False}
# StarRadius {'choices': 'positive value', 'deprecated': True, 'description': 'Radius of the star used together with StarTemperature for computing the flux.', 'hint': "Use key 'radius' for Nbody objects.", 'newname': 'none', 'type': 'double', 'unitsupport': False}
# StarTemperature {'choices': 'positive value', 'deprecated': True, 'description': 'Radius of the star used together with StarRadius for computing the flux.', 'hint': "Use key 'temperature' for Nbody objects.", 'newname': 'none', 'type': 'double', 'unitsupport': False}
# StellarRotation {'choices': '', 'default': 0.1, 'deprecated': True, 'description': 'For inner boundary = boundary layer: Stellar rotation rate (azimuthal velocity of the surface) in terms of Keplerian angular velocity at the inner boundary.', 'hint': 'InnerBoundaryVaziKeplerianFactor, InnerBoundaryVazi = keplerian', 'newname': 'none'}
# StsNu {'choices': 'positive value', 'default': '0.01', 'deprecated': True, 'description': 'Set the value of the viscosity for the STS module.', 'hint': 'The STS module has been removed.', 'newname': 'none', 'type': 'double', 'unitsupport': False}
# Temperaturecgs0 {'choices': 'positive value', 'default': 'none', 'deprecated': True, 'description': 'Set the reference temperature in cgs units.', 'hint': "Use Temperature0 instead. Append a 'K' to the value to set the temperature in Kelvin.", 'newname': 'none', 'type': 'double', 'unitsupport': False}
# VISCOSITY {'choices': '', 'default': 0, 'deprecated': True, 'description': 'Set a constant kinetic viscosity.', 'newname': 'ConstantViscosity'}
# VRadIn {'choices': '', 'default': 0.0016, 'deprecated': True, 'description': 'For inner boundary = boundary layer: value of v_rad at inner boundary in terms of Keplerian velocity v_kepler at the inner boundary.', 'hint': 'InnerBoundaryVradKeplerianFactor, InnerBoundaryVrad = keplerian', 'newname': 'none'}
# ViscosityInCGS {'choices': 'yes, no', 'default': False, 'deprecated': True, 'description': 'Interpret the value of constant viscosity to be in cgs.', 'hint': "Use the 'ConstantViscosity' key instead. It supports specifying units.", 'newname': 'none', 'type': 'bool', 'unitsupport': False}
# discmass {'choices': '', 'default': 0.01, 'deprecated': True, 'description': 'In case of SetSigma0=yes, use this mass as diskmass.', 'newname': 'DiskMass'}
# massoverflow {'choices': 'yes, no', 'default': False, 'deprecated': True, 'description': 'Enable a constant massflow coming though the outer boundary.', 'newname': 'RocheLobeOverflow'}
# mofaveragingtime {'choices': '', 'default': 10, 'deprecated': True, 'description': '?', 'newname': 'ROFAveragingTime'}
# mofgamma {'choices': '', 'default': 0.5, 'deprecated': True, 'description': '?', 'newname': 'ROFGamma'}
# mofplanet {'choices': '', 'default': 1, 'deprecated': True, 'description': '?', 'newname': 'ROFPlanet'}
# moframpingtime {'choices': '', 'default': 30, 'deprecated': True, 'description': 'Gradual increase for the mass overflow.', 'newname': 'ROFRampingTime'}
# moftemperature {'choices': '', 'default': '1000.0 K', 'deprecated': True, 'description': '?', 'newname': 'ROFTemperature'}
# mofvalue {'choices': '', 'default': '1e-08', 'deprecated': True, 'description': '?', 'newname': 'ROFValue'}
# variableTransfer {'choices': '', 'default': False, 'deprecated': True, 'description': '?', 'newname': 'ROFVariableTransfer'}
# zbufferMaxAngle {'choices': '', 'default': 0.17453292519943295, 'deprecated': True, 'description': '', 'newname': 'none'}
# zbufferSize {'choices': '', 'default': 100, 'deprecated': True, 'description': '', 'newname': 'none'}

# %%
with open("new_parameters.yml", "w") as outfile:
    yaml.dump(new_params, outfile, width=float("inf"))

# %%
with open("deprecated_parameters.yml", "w") as outfile:
    yaml.dump(deprecated_params, outfile, width=float("inf"))

# %%
for key, val in new_params.items():
    if "oldname" in val:
        print(key, val["oldname"])
# Out:
# Nmonitor Ninterm
# ViscousAlpha AlphaViscosity
# ConstantViscosity Viscosity

# %%
with open("deprecated_parameters.yml", "r") as infile:
    deprecated = yaml.safe_load(infile)

for key, val in deprecated.items():
    try:
        newname = val["newname"]
    except KeyError:
        print(f"!!!!!!!!!!! '{key}' does not have 'newname' yet, if it's removed without replacement set 'newname' to 'none'")
        continue
    if newname == "none":
        if "hint" in val:
            hint = val["hint"]
            print(f"'{key}': have a look at {hint}")
        else:
            print(f"'{key}' removed without replacement")
    else:
        print(f"'{key}' renamed to '{val['newname']}'")
# Out:
# 'ALPHAVISCOSITY' renamed to 'ViscousAlpha'
# 'Adiabatic': have a look at EquationOfState: Ideal
# 'AlphaThreshold' removed without replacement
# 'CoolingRadiativeLocal': have a look at SurfaceCooling: thermal
# 'CoolingScurve': have a look at SurfaceCooling: scurve
# 'DT' renamed to 'MonitorTimestep'
# 'DebugOutputs' removed without replacement
# 'DomegaDrZero': have a look at OuterBoundaryAzi = zeroshear
# 'ExplicitViscosity': have a look at Set ViscousAlpha > 0 or ConstantViscosity > 0
# 'ForcedCircular' removed without replacement
# 'HeatingStar': have a look at Set temperature of any Nbody object > 0 to enable irradiation from this object.
# 'HeatingStarFactor': have a look at Change the temperature of the Nbody object to modulate the heating.
# 'HeatingStarRampingTime': have a look at Use key 'irradiation ramp-up time' for Nbody objects.
# 'HeatingStarSimple': have a look at This is now the only option.
# 'IntegratePlanets' removed without replacement
# 'NSEC' renamed to 'Naz'
# 'NTOT' renamed to 'Nsnapshots'
# 'Ninterm' renamed to 'Nmonitor'
# 'StarRadius': have a look at Use key 'radius' for Nbody objects.
# 'StarTemperature': have a look at Use key 'temperature' for Nbody objects.
# 'StellarRotation': have a look at InnerBoundaryVaziKeplerianFactor, InnerBoundaryVazi = keplerian
# 'StsNu': have a look at The STS module has been removed.
# 'Temperaturecgs0': have a look at Use Temperature0 instead. Append a 'K' to the value to set the temperature in Kelvin.
# 'VISCOSITY' renamed to 'ConstantViscosity'
# 'VRadIn': have a look at InnerBoundaryVradKeplerianFactor, InnerBoundaryVrad = keplerian
# 'ViscosityInCGS': have a look at Use the 'ConstantViscosity' key instead. It supports specifying units.
# 'discmass' renamed to 'DiskMass'
# 'massoverflow' renamed to 'RocheLobeOverflow'
# 'mofaveragingtime' renamed to 'ROFAveragingTime'
# 'mofgamma' renamed to 'ROFGamma'
# 'mofplanet' renamed to 'ROFPlanet'
# 'moframpingtime' renamed to 'ROFRampingTime'
# 'moftemperature' renamed to 'ROFTemperature'
# 'mofvalue' renamed to 'ROFValue'
# 'variableTransfer' renamed to 'ROFVariableTransfer'
# 'zbufferMaxAngle' removed without replacement
# 'zbufferSize' removed without replacement

# %%
with open("deprecated_parameters.yml", "r") as infile:
    deprecated = yaml.safe_load(infile)

replacements = {}
for key, val in deprecated.items():
    newname = val["newname"]
    replacements[key] = {"newname": newname}
    if newname == "none":
        if "hint" in val:
            replacements[key]["hint"] = val["hint"]
replacements
# Out:
# {'ALPHAVISCOSITY': {'newname': 'ViscousAlpha'},
#  'Adiabatic': {'newname': 'none', 'hint': 'EquationOfState: Ideal'},
#  'AlphaThreshold': {'newname': 'none'},
#  'CoolingRadiativeLocal': {'newname': 'none',
#   'hint': 'SurfaceCooling: thermal'},
#  'CoolingScurve': {'newname': 'none', 'hint': 'SurfaceCooling: scurve'},
#  'DT': {'newname': 'MonitorTimestep'},
#  'DebugOutputs': {'newname': 'none'},
#  'DomegaDrZero': {'newname': 'none', 'hint': 'OuterBoundaryAzi = zeroshear'},
#  'ExplicitViscosity': {'newname': 'none',
#   'hint': 'Set ViscousAlpha > 0 or ConstantViscosity > 0'},
#  'ForcedCircular': {'newname': 'none'},
#  'HeatingStar': {'newname': 'none',
#   'hint': 'Set temperature of any Nbody object > 0 to enable irradiation from this object.'},
#  'HeatingStarFactor': {'newname': 'none',
#   'hint': 'Change the temperature of the Nbody object to modulate the heating.'},
#  'HeatingStarRampingTime': {'newname': 'none',
#   'hint': "Use key 'irradiation ramp-up time' for Nbody objects."},
#  'HeatingStarSimple': {'newname': 'none',
#   'hint': 'This is now the only option.'},
#  'IntegratePlanets': {'newname': 'none'},
#  'NSEC': {'newname': 'Naz'},
#  'NTOT': {'newname': 'Nsnapshots'},
#  'Ninterm': {'newname': 'Nmonitor'},
#  'StarRadius': {'newname': 'none',
#   'hint': "Use key 'radius' for Nbody objects."},
#  'StarTemperature': {'newname': 'none',
#   'hint': "Use key 'temperature' for Nbody objects."},
#  'StellarRotation': {'newname': 'none',
#   'hint': 'InnerBoundaryVaziKeplerianFactor, InnerBoundaryVazi = keplerian'},
#  'StsNu': {'newname': 'none', 'hint': 'The STS module has been removed.'},
#  'Temperaturecgs0': {'newname': 'none',
#   'hint': "Use Temperature0 instead. Append a 'K' to the value to set the temperature in Kelvin."},
#  'VISCOSITY': {'newname': 'ConstantViscosity'},
#  'VRadIn': {'newname': 'none',
#   'hint': 'InnerBoundaryVradKeplerianFactor, InnerBoundaryVrad = keplerian'},
#  'ViscosityInCGS': {'newname': 'none',
#   'hint': "Use the 'ConstantViscosity' key instead. It supports specifying units."},
#  'discmass': {'newname': 'DiskMass'},
#  'massoverflow': {'newname': 'RocheLobeOverflow'},
#  'mofaveragingtime': {'newname': 'ROFAveragingTime'},
#  'mofgamma': {'newname': 'ROFGamma'},
#  'mofplanet': {'newname': 'ROFPlanet'},
#  'moframpingtime': {'newname': 'ROFRampingTime'},
#  'moftemperature': {'newname': 'ROFTemperature'},
#  'mofvalue': {'newname': 'ROFValue'},
#  'variableTransfer': {'newname': 'ROFVariableTransfer'},
#  'zbufferMaxAngle': {'newname': 'none'},
#  'zbufferSize': {'newname': 'none'}}
