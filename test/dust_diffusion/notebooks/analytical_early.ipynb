# %%
import numpy as np
import matplotlib.pyplot as plt
import astropy.units as u
import astropy.constants as const
from tqdm import tqdm

# %%
Ms = 0.5*u.solMass

L0 = 1*u.au
M0 = 1*u.solMass
T0 = np.sqrt(L0**3/(M0*const.G)).to("yr")

deltar = 1*u.au
rmed = 10*u.au
rmin = rmed-deltar
rmax = rmed+deltar

rmin = 1*u.au
rmax = 40*u.au

Ncells = 1000
ris = np.linspace(rmin, rmax, Ncells+1)
r = 0.5*(ris[1:] + ris[:-1])

alpha = 1e-2
h0 = 0.040613
flaring = 0.25
# h0 = 0.05
# flaring = 0.0

sigma0 = (20*u.g/u.cm**2).to(M0/L0**2)

particle_density = (2.65*u.g/u.cm**3).to(M0/L0**3)
particle_size = (1e-5*u.cm).to(L0)

h = h0*r.to_value("au")**flaring

vK = np.sqrt(const.G*Ms/r).to(L0/T0)
OmegaK = (vK/r).to(1/T0)
H = (h*r).to(L0)
cs = (h*vK).to(L0/T0)

sigmag = sigma0 * r.to_value("au")**-1
rhog = sigmag / (np.sqrt(2*np.pi)*H)
rhog = rhog.to(M0/L0**3)

tstop = (particle_size*particle_density/(rhog*cs)).to(T0)
St = tstop * OmegaK
St = St.decompose()

# Youdin & Lithwick 2007 Eq. 37
Sc = (1 + St**2)**2  / (1 + 4*St**2)

Dg = alpha*cs*H
Dg = Dg.to(L0**2/T0)
Dd = Dg/Sc
Dd = Dd.to(L0**2/T0)

dt = 0.01*T0

mean_kick = (Dd/rhog*np.gradient(rhog, r)*0.01*T0).to(L0)
width_kick = np.sqrt(2*Dd*dt).to(L0)

# %%
St
# Out:
# <Quantity [3.38604747e-06, 3.51557749e-06, 3.64510750e-06, 3.77463752e-06,
#            3.90416754e-06, 4.03369755e-06, 4.16322757e-06, 4.29275758e-06,
#            4.42228760e-06, 4.55181762e-06, 4.68134763e-06, 4.81087765e-06,
#            4.94040767e-06, 5.06993768e-06, 5.19946770e-06, 5.32899771e-06,
#            5.45852773e-06, 5.58805775e-06, 5.71758776e-06, 5.84711778e-06,
#            5.97664779e-06, 6.10617781e-06, 6.23570783e-06, 6.36523784e-06,
#            6.49476786e-06, 6.62429787e-06, 6.75382789e-06, 6.88335791e-06,
#            7.01288792e-06, 7.14241794e-06, 7.27194795e-06, 7.40147797e-06,
#            7.53100799e-06, 7.66053800e-06, 7.79006802e-06, 7.91959804e-06,
#            8.04912805e-06, 8.17865807e-06, 8.30818808e-06, 8.43771810e-06,
#            8.56724812e-06, 8.69677813e-06, 8.82630815e-06, 8.95583816e-06,
#            9.08536818e-06, 9.21489820e-06, 9.34442821e-06, 9.47395823e-06,
#            9.60348824e-06, 9.73301826e-06, 9.86254828e-06, 9.99207829e-06,
#            1.01216083e-05, 1.02511383e-05, 1.03806683e-05, 1.05101984e-05,
#            1.06397284e-05, 1.07692584e-05, 1.08987884e-05, 1.10283184e-05,
#            1.11578484e-05, 1.12873785e-05, 1.14169085e-05, 1.15464385e-05,
#            1.22035542e-04, 1.22165072e-04, 1.22294602e-04, 1.22424132e-04,
#            1.22553662e-04, 1.22683192e-04, 1.22812722e-04, 1.22942252e-04,
#            1.23071782e-04, 1.23201312e-04, 1.23330842e-04, 1.23460372e-04,
#            1.23589902e-04, 1.23719432e-04, 1.23848962e-04, 1.23978492e-04,
#            1.24108022e-04, 1.24237552e-04, 1.24367083e-04, 1.24496613e-04,
#            1.24626143e-04, 1.24755673e-04, 1.24885203e-04, 1.25014733e-04,
#            1.25144263e-04, 1.25273793e-04, 1.25403323e-04, 1.25532853e-04,
#            1.25662383e-04, 1.25791913e-04, 1.25921443e-04, 1.26050973e-04,
#            1.26180503e-04, 1.26310033e-04, 1.26439563e-04, 1.26569093e-04,
#            1.26698623e-04, 1.26828153e-04, 1.26957683e-04, 1.27087213e-04,
#            1.27216743e-04, 1.27346273e-04, 1.27475803e-04, 1.27605333e-04,
#            1.27734863e-04, 1.27864393e-04, 1.27993923e-04, 1.28123453e-04,
#            1.28252983e-04, 1.28382513e-04, 1.28512043e-04, 1.28641573e-04,
#            1.28771103e-04, 1.28900633e-04, 1.29030163e-04, 1.29159693e-04,
#            1.29289223e-04, 1.29418753e-04, 1.29548283e-04, 1.29677813e-04,
#            1.29807343e-04, 1.29936873e-04, 1.30066403e-04, 1.30195933e-04,
#            1.30325463e-04, 1.30454993e-04, 1.30584523e-04, 1.30714053e-04,
#            1.30843583e-04, 1.30973113e-04, 1.31102643e-04, 1.31232173e-04,
#            1.31361703e-04, 1.31491233e-04, 1.31620763e-04, 1.31750293e-04,
#            1.31879823e-04, 1.32009353e-04, 1.32138883e-04, 1.32268413e-04,
#            1.32397943e-04, 1.32527474e-04, 1.32657004e-04, 1.32786534e-04]>

# %%
import h5py
with h5py.File("../fargo_particle_data.hdf5", "r") as infile:
    d = {}
    for key in infile:
        d[key] = infile[key][:]

# %%
fig, ax = plt.subplots()
ax.plot(r, St)
ax.plot(d["r"], d["St"], ls="--")
ax.set_yscale("log")
ax.set_xscale("log")
ax.set_ylabel("St")

fig, ax = plt.subplots()
ax.plot(r, Dd)
ax.plot(d["r"], d["Dd"], ls="--")
ax.set_yscale("log")
ax.set_xscale("log")
ax.set_ylabel("Dd")
# Out:
# Text(0, 0.5, 'Dd')

# %%
fig, ax = plt.subplots()
ax.plot(r, -mean_kick)
ax.plot(d["r"], -d["mean"], ls="--")
ax.set_yscale("log")
ax.set_xscale("log")
ax.set_ylabel("-mean")

fig, ax = plt.subplots()
ax.plot(r, width_kick)
ax.plot(d["r"], d["sigma"], ls="--")
ax.set_yscale("log")
ax.set_xscale("log")
ax.set_ylabel("kick width")
# Out:
# Text(0, 0.5, 'kick width')

# %%
fig, ax = plt.subplots()
ax.plot(r, rhog)
ax.plot(d["r"], d["rho"], ls="--")
ax.set_yscale("log")
ax.set_xscale("log")
ax.set_ylabel("rhog")

fig, ax = plt.subplots()
ax.plot(r, -np.gradient(rhog, r))
ax.plot(d["r"], -d["drho_dr"], ls="--")
ax.set_yscale("log")
ax.set_xscale("log")
ax.set_ylabel("-drhog_dr")
# Out:
# Text(0, 0.5, '-drhog_dr')

# %% [markdown]
# Radial advection-diffusion equation according to Charnoz et al. 2011 Eq. (28)
#
# $$\frac{dC}{dt} = \frac{1}{\rho_g r} \frac{\partial}{\partial r} ( -r V_r \rho_g C + r \rho_g D_d \frac{\partial C}{\partial r} )$$
#
# with the dust concentration
#
# $C = \frac{\rho_d}{\rho_g}$.
#
# $V_r$ is the gas radial velocity which is taken to be zero.
#
# Then the equation to solves becomes the diffusion equation
# $$\frac{dC}{dt} = \frac{1}{\rho_g r} \frac{\partial}{\partial r} (r \rho_g D_d \frac{\partial C}{\partial r})$$

# %%
Nbound = 10
def boundaries(C):
    C[:Nbound] = 0
    C[-Nbound:] = 0
    return C

def rhs(C):
    dCdr = np.gradient(C, r, edge_order=2)
    X = r*rhog*Dd*dCdr
    dXdr = np.gradient(X, r, edge_order=2)
    return dXdr / (r*rhog)

# %%
C = np.exp(- 0.5*(r.to_value("au") - 10)**2/(0.0001**2))

t = 0*u.yr
dt = 0.00001*u.yr
tfinal = 0.0001*u.yr

t_save = tfinal/100
N_save = int((tfinal / t_save).decompose()) + 1
times_save = np.linspace(0, tfinal, N_save)
saves = np.zeros((len(times_save), Ncells))


fig, ax = plt.subplots()

ax.plot(r, C, label = "t = 0 yr")

nplot = 0

saves[0] = C


for n in tqdm(range(N_save-1)):
    while t < times_save[n+1]:
        
        C = boundaries(C)
        dCdt = rhs(C).decompose()
        C += (dt*dCdt).decompose().value
        t += dt        
        if t > nplot*tfinal/10:
            ax.plot(r, C, label = f"t={t:.3g}")
            nplot += 1
    
    saves[n+1] = C

ax.legend()
ax.set_yscale("log")
ax.set_ylim(bottom=1e-3, top=1)
# ax.set_ylim(top=1)
dr = 1e-3
ax.set_xlim(10-dr, 10+dr)
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 1181.60it/s]
# (9.999, 10.001)

# %%
sigmads = np.zeros_like(saves)
for n, C in enumerate(saves):
    rhod = C*rhog
    sigmads[n] = rhod*(np.sqrt(2*np.pi)*H)

np.save("../analytical_data/analytic_profiles", sigmads)
np.save("../analytical_data/analytic_times", times_save.to_value("yr"))
np.save("../analytical_data/analytic_radii", r.to_value("au"))

# %%
fig, ax = plt.subplots()

times = times_save.to_value("yr")

tplot = 2500
n = np.argmin(np.abs(times - tplot))
X = r
rhod = saves[n]
sigmad = rhod/(np.sqrt(2*np.pi)*H)
Y = sigmad / np.max(sigmad)
ax.plot(X, Y, label = f"t={times[n]}")

tplot = 5000
n = np.argmin(np.abs(times - tplot))
rhod = saves[n]
sigmad = rhod/(np.sqrt(2*np.pi)*H)
Y = sigmad / np.max(sigmad)
ax.plot(X, Y, label = f"t={times[n]}")

ax.set_yscale("log")
ax.set_ylim(bottom=1e-3,top=1)
ax.legend(loc="best")
ax.set_xlim(left=0, right=20)

ax.set_xticks(range(0,21));

# %%
fig, ax = plt.subplots()
ax.plot(r, rhog)
ax.set_yscale("log")
ax.set_ylabel("rhog")
# Out:
# Text(0, 0.5, 'rhog')

# %%
ls = np.load("../analytical_data/analytic_profiles.npy")
lt = np.load("../analytical_data/analytic_times.npy")
lr = np.load("../analytical_data/analytic_radii.npy")

# %%
fig, ax = plt.subplots()

tplot = 2500
n = np.argmin(np.abs(lt - tplot))
ax.plot(rcs, ls[n], label = f"t={lt[n]}")

tplot = 5000
n = np.argmin(np.abs(lt - tplot))
ax.plot(rcs, ls[n], label = f"t={lt[n]}")

ax.set_yscale("log")
ax.set_ylim(bottom=1e-3,top=1)
ax.legend(loc="best")
ax.set_xlim(left=0, right=20)
# Out:
# (0.0, 20.0)

# %%
lr
# Out:
# array([ 1.00975,  1.02925,  1.04875, ..., 39.95125, 39.97075, 39.99025])

# %%
#!pip install py-pde h5py pandas pyfftw tqdm
from pde import PDE, CartesianGrid, MemoryStorage, ScalarField, plot_kymograph

# Expanded definition of the PDE
diffusivity = "1.01 + tanh(x)"
term_1 = f"({diffusivity}) * laplace(c)"
term_2 = f"dot(gradient({diffusivity}), gradient(c))"
eq = PDE({"c": f"{term_1} + {term_2}"}, bc={"value": 0})


grid = CartesianGrid([[-5, 5]], 64)  # generate grid
field = ScalarField(grid, 1)  # generate initial condition

storage = MemoryStorage()  # store intermediate information of the simulation
res = eq.solve(field, 100, dt=1e-3, tracker=storage.tracker(1))  # solve the PDE

fig, ax = plt.subplots(dpi=150)

plot_kymograph(storage, ax=ax)  # visualize the result in a space-time plot

# %%
Ms = 0.5*u.solMass

r0 = 1*u.au
alpha = 1e-2
h0 = 0.040613
flaring = 0.25
beta = -1

H0 = h0*r0

sigmag0 = 20*u.g/u.cm**2
rhog0 = sigmag0 / (np.sqrt(2*np.pi)*H0)

particle_density = 2.65*u.g/u.cm**3
particle_size = 1e-5*u.cm

vK0 = np.sqrt(const.G*Ms/r0)
OmegaK0 = vK0/r0
cs0 = h0*vK0

ts0 = particle_density*particle_size/(rhog0*cs0)
St0 = ts0 * OmegaK0

Dg0 = alpha*cs0*h0

# Youdin & Lithwick 2007 Eq. 37
# Sc = (1 + St**2)**2  / (1 + 4*St**2)

# %%
St = f"{St0} * x**(-{beta} - {flaring})"
Sc = f"(1 + ({St})**2)**2 / (1 + 4*({St})**2)"
Dd = f"{Dg0} * r**(0.5+{flaring}) / {Sc}"

# %%
from sympy import latex
latex(St)
latex(Sc)
latex(Dd)
# Out:
# '\\mathtt{\\text{9.528356686578309e-11 m(3/2) solMass(1/2) / (AU(1/2) kg(1/2) s)* r**(0.5+0.25) / (1 + (3.321282463886075e-06 * x**(--1 - 0.25))**2)**2/(1 + 4*(3.321282463886075e-06 * x**(--1 - 0.25))**2)}}'

# %%
#!pip install py-pde h5py pandas pyfftw tqdm
from pde import PDE, CartesianGrid, MemoryStorage, ScalarField, plot_kymograph

# Expanded definition of the PDE
# diffusivity = "1e-2"
diffusivity = f"({Dd})"
gamma = "-1"
term_1 = f"({gamma}) / x * {diffusivity} * d_dx(c)"
term_2 = f"d_dx({diffusivity}) * d_dx(c)"
term_3 = f"{diffusivity} * laplace(c)"
rhs = 
eq = PDE({"c": rhs}, bc={"value": 0})


grid = CartesianGrid([[-5, 5]], 512)  # generate grid
dinit = np.exp(- 0.5*(grid.cell_coords[:,0])**2/(0.1**2))


field = ScalarField(grid, dinit)  # generate initial condition

storage = MemoryStorage()  # store intermediate information of the simulation
res = eq.solve(field, 100, dt=1e-3, tracker=storage.tracker(1))  # solve the PDE

fig, ax = plt.subplots(dpi=150)

plot_kymograph(storage, ax=ax)  # visualize the result in a space-time plot
# Out:
# ValueError: Error from parse_expr with transformed code: "(-Integer (1 ))/Symbol ('x' )*(Float ('9.528356686578309e-11' )Function ('m' )(Integer (3 )/Integer (2 ))Function ('solMass' )(Integer (1 )/Integer (2 ))/(Function ('AU' )(Integer (1 )/Integer (2 ))Function ('kg' )(Integer (1 )/Integer (2 ))Symbol ('s' ))*Symbol ('r' )**(Float ('0.5' )+Float ('0.25' ))/(Integer (1 )+(Float ('3.321282463886075e-06' )*Symbol ('x' )**(--Integer (1 )-Float ('0.25' )))**Integer (2 ))**Integer (2 )/(Integer (1 )+Integer (4 )*(Float ('3.321282463886075e-06' )*Symbol ('x' )**(--Integer (1 )-Float ('0.25' )))**Integer (2 )))*Function ('d_dx' )(c )+Function ('d_dx' )((Float ('9.528356686578309e-11' )Function ('m' )(Integer (3 )/Integer (2 ))Function ('solMass' )(Integer (1 )/Integer (2 ))/(Function ('AU' )(Integer (1 )/Integer (2 ))Function ('kg' )(Integer (1 )/Integer (2 ))Symbol ('s' ))*Symbol ('r' )**(Float ('0.5' )+Float ('0.25' ))/(Integer (1 )+(Float ('3.321282463886075e-06' )*Symbol ('x' )**(--Integer (1 )-Float ('0.25' )))**Integer (2 ))**Integer (2 )/(Integer (1 )+Integer (4 )*(Float ('3.321282463886075e-06' )*Symbol ('x' )**(--Integer (1 )-Float ('0.25' )))**Integer (2 ))))*Function ('d_dx' )(c )+(Float ('9.528356686578309e-11' )Function ('m' )(Integer (3 )/Integer (2 ))Function ('solMass' )(Integer (1 )/Integer (2 ))/(Function ('AU' )(Integer (1 )/Integer (2 ))Function ('kg' )(Integer (1 )/Integer (2 ))Symbol ('s' ))*Symbol ('r' )**(Float ('0.5' )+Float ('0.25' ))/(Integer (1 )+(Float ('3.321282463886075e-06' )*Symbol ('x' )**(--Integer (1 )-Float ('0.25' )))**Integer (2 ))**Integer (2 )/(Integer (1 )+Integer (4 )*(Float ('3.321282463886075e-06' )*Symbol ('x' )**(--Integer (1 )-Float ('0.25' )))**Integer (2 )))*Function ('laplace' )(c )"
#
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#
#   File "/home/rometsch/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3441, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-136-2c3d56e8bede>", line 11, in <module>
#     eq = PDE({"c": f"{term_1} + {term_2} + {term_3}"}, bc={"value": 0})
#
#   File "/home/rometsch/.local/lib/python3.8/site-packages/pde/pdes/pde.py", line 149, in __init__
#     rhs_expr = ScalarExpression(
#
#   File "/home/rometsch/.local/lib/python3.8/site-packages/pde/tools/expressions.py", line 566, in __init__
#     sympy_expr = parse_expr_guarded(
#
#   File "/home/rometsch/.local/lib/python3.8/site-packages/pde/tools/expressions.py", line 180, in parse_expr_guarded
#     return sympy_parser.parse_expr(expression, local_dict=local_dict)  # type: ignore
#
#   File "/home/rometsch/.local/lib/python3.8/site-packages/sympy/parsing/sympy_parser.py", line 1101, in parse_expr
#     raise e from ValueError(f"Error from parse_expr with transformed code: {code!r}")
#
#   File "/home/rometsch/.local/lib/python3.8/site-packages/sympy/parsing/sympy_parser.py", line 1092, in parse_expr
#     rv = eval_expr(code, local_dict, global_dict)
#
#   File "/home/rometsch/.local/lib/python3.8/site-packages/sympy/parsing/sympy_parser.py", line 907, in eval_expr
#     expr = eval(
#
#   File "<string>", line 1
#     (-Integer (1 ))/Symbol ('x' )*(Float ('9.528356686578309e-11' )Function ('m' )(Integer (3 )/Integer (2 ))Function ('solMass' )(Integer (1 )/Integer (2 ))/(Function ('AU' )(Integer (1 )/Integer (2 ))Function ('kg' )(Integer (1 )/Integer (2 ))Symbol ('s' ))*Symbol ('r' )**(Float ('0.5' )+Float ('0.25' ))/(Integer (1 )+(Float ('3.321282463886075e-06' )*Symbol ('x' )**(--Integer (1 )-Float ('0.25' )))**Integer (2 ))**Integer (2 )/(Integer (1 )+Integer (4 )*(Float ('3.321282463886075e-06' )*Symbol ('x' )**(--Integer (1 )-Float ('0.25' )))**Integer (2 )))*Function ('d_dx' )(c )+Function ('d_dx' )((Float ('9.528356686578309e-11' )Function ('m' )(Integer (3 )/Integer (2 ))Function ('solMass' )(Integer (1 )/Integer (2 ))/(Function ('AU' )(Integer (1 )/Integer (2 ))Function ('kg' )(Integer (1 )/Integer (2 ))Symbol ('s' ))*Symbol ('r' )**(Float ('0.5' )+Float ('0.25' ))/(Integer (1 )+(Float ('3.321282463886075e-06' )*Symbol ('x' )**(--Integer (1 )-Float ('0.25' )))**Integer (2 ))**Integer (2 )/(Integer (1 )+Integer (4 )*(Float ('3.321282463886075e-06' )*Symbol ('x' )**(--Integer (1 )-Float ('0.25' )))**Integer (2 ))))*Function ('d_dx' )(c )+(Float ('9.528356686578309e-11' )Function ('m' )(Integer (3 )/Integer (2 ))Function ('solMass' )(Integer (1 )/Integer (2 ))/(Function ('AU' )(Integer (1 )/Integer (2 ))Function ('kg' )(Integer (1 )/Integer (2 ))Symbol ('s' ))*Symbol ('r' )**(Float ('0.5' )+Float ('0.25' ))/(Integer (1 )+(Float ('3.321282463886075e-06' )*Symbol ('x' )**(--Integer (1 )-Float ('0.25' )))**Integer (2 ))**Integer (2 )/(Integer (1 )+Integer (4 )*(Float ('3.321282463886075e-06' )*Symbol ('x' )**(--Integer (1 )-Float ('0.25' )))**Integer (2 )))*Function ('laplace' )(c )
#                                                                    ^
# SyntaxError: invalid syntax
