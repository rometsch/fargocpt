# %%
import sys
sys.path.append("../../Tools")
from overview import Overview

# %%
# !ls output
# Out:
# a0.6_idm0_e0.1	a0.6_idm1_e0.1	idm0_e0.1  idm0_e0.3  idm1_e0.2
# a0.6_idm0_e0.2	a0.6_idm1_e0.2	idm0_e0.2  idm1_e0.1  idm1_e0.3

# %%
# %matplotlib widget
vars = ["0:Nbody", "2:mass density", "2:velocity azimuthal", "0:eccentricity", "0:mass"]
ow = Overview("output/a0.6_idm0_e0.2", vars=vars)
ow.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/ipympl/backend_nbagg.py in _handle_message(self, object, content, buffers)
#     277
#     278         else:
# --> 279             self.manager.handle_json(content)
#     280
#     281     def send_json(self, content):
#
# ~/.local/lib/python3.8/site-packages/matplotlib/backends/backend_webagg_core.py in handle_json(self, content)
#     460
#     461     def handle_json(self, content):
# --> 462         self.canvas.handle_event(content)
#     463
#     464     def refresh_all(self):
#
# ~/.local/lib/python3.8/site-packages/matplotlib/backends/backend_webagg_core.py in handle_event(self, event)
#     264         handler = getattr(self, 'handle_{0}'.format(e_type),
# ...

# %%
# %matplotlib widget
vars = ["0:Nbody", "2:mass density", "2:velocity azimuthal", "0:eccentricity", "0:mass"]
ow = Overview("output/a0.6_idm1_e0.2", vars=vars)
ow.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/ipympl/backend_nbagg.py in _handle_message(self, object, content, buffers)
#     277
#     278         else:
# --> 279             self.manager.handle_json(content)
#     280
#     281     def send_json(self, content):
#
# ~/.local/lib/python3.8/site-packages/matplotlib/backends/backend_webagg_core.py in handle_json(self, content)
#     460
#     461     def handle_json(self, content):
# --> 462         self.canvas.handle_event(content)
#     463
#     464     def refresh_all(self):
#
# ~/.local/lib/python3.8/site-packages/matplotlib/backends/backend_webagg_core.py in handle_event(self, event)
#     264         handler = getattr(self, 'handle_{0}'.format(e_type),
# ...
